# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def isToeplitzMatrix(matrix):
    for r in range(len(matrix)):
        for c in range(len(matrix[0])):
            if r > 0 and c > 0 and matrix[r-1][c-1] != matrix[r][c]:
                return False
    return True

matrix = [[1,2,3,4],[5,1,2,3],[9,5,1,2]]
isToeplitzMatrix(matrix)
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def transpose(A):
    R = len(A)
    C = len(A[0])
    ans = [[0 for _ in range(R)] for _ in range(C)]
    for r in range(R):
        for c in range(C):
            ans[c][r] = A[r][c]
    return ans

A = [[1,2,3], [4,5,6], [7,8,9]]
transpose(A)
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def rotate(matrix):
    n = len(matrix)
    for i in range((n + 1) // 2):
        for j in range(n // 2):
            temp = matrix[n - 1 - j][i]
            matrix[n - 1 - j][i] = matrix[n - 1 - i][n - j - 1]
            matrix[n - 1 - i][n - j - 1] = matrix[j][n - 1 - i]
            matrix[j][n - 1 - i] = matrix[i][j]
            matrix[i][j] = temp
    return matrix
            
matrix = [[1,2,3], [4,5,6], [7,8,9]]
rotate(matrix)
# Out:
# [[7, 4, 1], [8, 5, 2], [9, 6, 3]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def maximumWealth(accounts):
    # Initialize the maximum wealth seen so far to 0 (the minimum wealth possible)
    maxWealthSoFar = 0
    
    # Iterate over accounts
    for account in accounts:
        # For each account, initialize the sum to 0
        currCustomerWealth = 0
        # Add the money in each bank
        for money in account:
            currCustomerWealth += money
        # Update the maximum wealth seen so far if the current wealth is greater
        maxWealthSoFar = max(maxWealthSoFar, currCustomerWealth)
    
    # Return the maximum wealth
    return maxWealthSoFar

accounts = [1,2,2,3,1]
maximumWealth(accounts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 19
#      16     return maxWealthSoFar
#      18 accounts = [1,2,2,3,1]
# ---> 19 maximumWealth(accounts)
#
# Cell In[6], line 10, in maximumWealth(accounts)
#       8 currCustomerWealth = 0
#       9 # Add the money in each bank
# ---> 10 for money in account:
#      11     currCustomerWealth += money
#      12 # Update the maximum wealth seen so far if the current wealth is greater
#
# TypeError: 'int' object is not iterable
